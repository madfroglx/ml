# %%
from sklearn import datasets
from sklearn import linear_model
from sklearn import model_selection
from matplotlib import pyplot as plt

# %%
iris = datasets.load_iris()
data = iris.data[:, 0:2][iris.target != 2]
print(data.shape)
target = iris.target[iris.target != 2]
print(target.shape)
# Out:
# (100, 2)
# (100,)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(data, target, train_size=0.9)
lr = linear_model.LogisticRegression()
lr.fit(X_train, y_train)
print(lr.score(X_test, y_test))
# Out:
# 1.0

# %%
# type_a = data[target != 2]
# type_b = data[target == 2]
# plt.scatter(type_a[:, 0:1], type_a[:,1:2], c = target)
# plt.scatter(type_b[:, 0:1], type_b[:,1:2] , c = target)
plt.scatter(data[:, 0:1], data[:,1:2], c = target)
plt.show()
